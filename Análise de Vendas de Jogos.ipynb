# %% [markdown]
# # ANÁLISE DAS VENDAS DE JOGOS (1980 - 2019)

# %%
#Importando as bibliotecas e definindo o número máximo de colunas e linhas


import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = 10
pd.options.display.max_rows = 20

# %%
#Comando para leitura do arquivo .csv
filename = 'Video_Games_Sales_as_at_22_Dec_2016.csv'
df = pd.read_csv(filename)

# %%
df.shape #quantidade de linhas e colunas (linhas, colunas)
# Out:
# (16719, 16)

# %%
df.columns #Nome de todas as colunas do arquivo
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df.head(10) #Algumas informações presentes no arquivo
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  ...  Critic_Count  User_Score  User_Count  Developer  Rating
# 0  Nintendo  ...          51.0           8       322.0   Nintendo       E
# ...

# %%
df.info() #informações das classes dos dados presentes nas colunas
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 1.6+ MB

# %%
df.min() #Valores mínimos
# Out:
# Year_of_Release    1980.00
# NA_Sales              0.00
# EU_Sales              0.00
# JP_Sales              0.00
# Other_Sales           0.00
# Global_Sales          0.01
# Critic_Score         13.00
# Critic_Count          3.00
# User_Count            4.00
# dtype: float64

# %%
df.max() #Valores máximos
# Out:
# Year_of_Release     2020.00
# NA_Sales              41.36
# EU_Sales              28.96
# JP_Sales              10.22
# Other_Sales           10.57
# Global_Sales          82.53
# Critic_Score          98.00
# Critic_Count         113.00
# User_Count         10665.00
# dtype: float64

# %%
plt.style.available #Lista de estilos disponíveis para os gráficos plt
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
#Gráfico de Quantidade de Jogos por Plataforma
plt.style.use('seaborn-dark')
platGenre = pd.crosstab(df.Platform,df.Genre)
platGenreTotal = platGenre.sum(axis=1).sort_values(ascending = False)
plt.figure(figsize=(12,10))
sns.barplot(y = platGenreTotal.index, x = platGenreTotal.values, orient='h')
plt.ylabel = "Plataforma"
plt.xlabel = "Quantidade de jogos"
plt.title('Quantidade de Jogos por Plataforma')
plt.show()

# %%
#Gráfico de Quantidade de Jogos por Gênero
plt.style.use('bmh')
df.groupby('Genre').size().sort_values().tail(20).plot(kind='bar', figsize=(8,8))
plt.title('Quantidade de Jogos por Gênero')
# Out:
# Text(0.5, 1.0, 'Quantidade de Jogos por Gênero')

# %%
#Gráfico das 10 empresas que mais publicaram jogos
plt.style.use('ggplot')
df.groupby('Publisher').size().sort_values().tail(10).plot(kind='barh', figsize=(7, 7))
plt.title('Gráfico das principais empresas de jogos')
plt.xlabel = 'Quantidade de Jogos'

# %%
#Código para armazenar os dados e manipulá-los

valores_vendas1= []
valores_vendas2= []
nomes = []
index = []

nomes_jogos= []
dic = []
for k in df.Name:
    nomes_jogos.append(k)
    dic.append(k)
for x in df.Global_Sales:
    valores_vendas1.append(x)
    dic.append(k)  
    
valores_vendas1.sort(reverse=True)
x=0
while x <= 4:
    valores_vendas2.append(valores_vendas1[x])
    x = x + 1
    
x=0    
while x <=(len(valores_vendas2) - 1):
    index.append((valores_vendas1.index(valores_vendas2[x])))
    nomes.append(nomes_jogos[index[x]])
    x = x + 1
    


# Gráfico de setores:
labels = nomes 
sizes = valores_vendas2
explode = (0.1, 0, 0, 0, 0)  # 'explode' a primeira fatia
colors = ['orange', 'gold', 'lightblue', 'gray', 'yellowgreen']
patches, texts = plt.pie(sizes, explode=explode, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc='lower left')
plt.axis('equal')
plt.tight_layout()
plt.title('Os 5 Jogos mais vendidos')
plt.show()
